# %% [markdown]
# ## Comments
# 1. single line #
# 2. multi line ''' '''

# %%
#hello
print("Hello")
# Out:
# Hello

# %%
"""

dbffjweofsefheufhe
dv
dv
dv

"""
print("hi")
# Out:
# hi

# %% [markdown]
# ## Variables

# %%
x = 5
x
# Out:
# 5

# %%
type(x)
# Out:
# int

# %%
y = 3.4
type(y)
# Out:
# float

# %%
z = "ta"
type(z)
# Out:
# str

# %%
a = "2323"
type(a)
# Out:
# str

# %%
x = 10

# %%
print(x)

fgg_f23 = 4
print(fgg_f23)
# Out:
# 10
# 4

# %%
x,y = "z", "o"
print(x)
print(y)
# Out:
# z
# o

# %%
fru = [1,2,3]
# Out:
# [1, 2, 3]

# %%
x="tharun"
def cv():
    global y2
    y2 = 'vijay'
    print(y2)
cv()
# Out:
# vijay

# %%
def cv2():
    print(y2)
cv2()
# Out:
# vijay

# %%
x = "vijay"
y = "kumar"
x+y
# Out:
# 'vijaykumar'

# %%
x = 5
y = 47
x+y
# Out:
# 52

# %%
x = "fg"
y = int(34)
x + y
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 3
#       1 x = "fg"
#       2 y = int(34)
# ----> 3 x + y
#
# TypeError: can only concatenate str (not "int") to str

# %%
x = "34"
int(x)
# Out:
# 34

# %%
c = 4j
print(c)
# Out:
# 4j

# %%
type(c)
# Out:
# complex

# %%
x = None
print(x)
# Out:
# None

# %%
type(x)
# Out:
# NoneType

# %%
c = b"hi"
print(c)
# Out:
# b'hi'

# %%
type(c)
# Out:
# bytes
